# %%
import sys

print(sys.executable)
# Out:
# c:\Users\braya\OneDrive\Documents\sports-probability-predictor\.venv\Scripts\python.exe

# %%
import pandas as pd
import numpy as np
import matplotlib
import sklearn

print("pandas:", pd.__version__)
print("numpy:", np.__version__)
print("matplotlib:", matplotlib.__version__)
print("scikit-learn:", sklearn.__version__)
# Out:
# pandas: 3.0.5
# numpy: 2.5.2
# matplotlib: 3.11.1
# scikit-learn: 1.9.0
